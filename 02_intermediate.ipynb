# %% [markdown]
# <a href="https://colab.research.google.com/github/moinuddin2406/Assignment-4/blob/main/02_intermediate.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random
print("High Low Game")

round = 5

def main():
  print("Welcome to the High Low Game")
  print("******************************")

  your_score = 0

  for i in range(round):
    print("Round", i+1)

    computer_number : int =random.randint(1,100)
    your_number : int = random.randint(1,100)
    print("Your number is" , your_number)

    choice:str = input("Do you think your number is higher or lower than the computer's number?")
    higher_and_correct:bool = choice == "higher" and your_number > computer_number
    lower_and_correct:bool = choice == "lower" and your_number < computer_number

    if higher_and_correct or lower_and_correct:
      print("you were right! The computer's number was" ,computer_number)
      your_score += 1
    else:
      print("Aww,that's incorrect.The computer's number was",computer_number)

    print("Your score is now", your_score)
    print()

  print("Thanks for playing!")

if __name__ == "__main__":
    main()
# Out:
# High Low Game
# Welcome to the High Low Game
# ******************************
# Round 1
# Your number is 59
# Do you think your number is higher or lower than the computer's number?higher
# Aww,that's incorrect.The computer's number was 64
# Your score is now 0
#
# Round 2
# Your number is 50
# Do you think your number is higher or lower than the computer's number?lower
# Aww,that's incorrect.The computer's number was 36
# Your score is now 0
#
# Round 3
# Your number is 98
# Do you think your number is higher or lower than the computer's number?higher
# you were right! The computer's number was 21
# Your score is now 1
#
# Round 4
# Your number is 28
# Do you think your number is higher or lower than the computer's number?lower
# you were right! The computer's number was 57
# Your score is now 2
#
# Round 5
# Your number is 53
# Do you think your number is higher or lower than the computer's number?lower
# you were right! The computer's number was 84
# Your score is now 3
#
# ...

# %%
print("***Planetary Weight Calculator***")
print("******************************************")
print("Welcome to the Planetary Weight Calculator")
print("******************************************")

def main():
    earth_weight = float(input("Enter your weight on Earth: "))

    gravity_ratios = {
        "Mercury": 0.38,
        "Venus": 0.91,
        "Mars": 0.38,
        "Jupiter": 2.34,
        "Saturn": 0.93,
        "Uranus": 0.92,
        "Neptune": 1.19
    }

    print("Select a planet to calculate your weight on that planet:")
    for planet in gravity_ratios:
        print(f"==> {planet}")

    planet_choice = input("Enter the name of the planet: ").title()

    if planet_choice in gravity_ratios:
        new_weight = earth_weight * gravity_ratios[planet_choice]
        print(f"Your weight on {planet_choice} is {new_weight:.2f} kg")
    else:
        print("Invalid planet choice. Please try again.")

if __name__ == "__main__":
    main()
# Out:
# ***Planetary Weight Calculator***
# ******************************************
# Welcome to the Planetary Weight Calculator
# ******************************************
# Enter your weight on Earth: 60
# Select a planet to calculate your weight on that planet:
# ==> Mercury
# ==> Venus
# ==> Mars
# ==> Jupiter
# ==> Saturn
# ==> Uranus
# ==> Neptune
# Enter the name of the planet: jupiter
# Your weight on Jupiter is 140.40 kg

# %%
print("***Lists and Dicts***")

my_list = ["apple", "banana", "cherry", "orange", "pear"]
print(my_list)

def access_elements(my_list, index):
    """Return the element at the specified index, or an error message if out of range"""
    if 0 <= index < len(my_list):
        return f"Element at index {index} is {my_list[index]}"
    return "Index out of range"

def modify_element(my_list, index, new_value):
    """Modify the element at the specified index with the new value."""
    if 0 <= index < len(my_list):
        old_value = my_list[index]
        my_list[index] = new_value
        return f"Element at index {index} modified from {old_value} to {new_value}"
    return "Index out of range"

def slice_list(my_list, start, end):
    """Return a new list containing the elements from the start index to end index (exclusive)."""
    if 0 <= start <= end <= len(my_list):
        return f"Sliced list: {my_list[start:end]}"
    return "Invalid slice indices!"

def list_game():
    print("Welcome to the List Manipulation Game")
    my_list = ["apple", "banana", "cherry", "orange", "pear"]
    while True:
        print("\nCurrent list:", my_list)
        print("Select an operation:")
        print("1. Access Element")
        print("2. Modify Element")
        print("3. Slice List")
        print("4. Quit")

        choice = input("Enter your choice (1/2/3/4): ")

        if choice == "1":
            index = int(input("Enter the index to access: "))
            result = access_elements(my_list, index)
            print(result)

        elif choice == "2":
            index = int(input("Enter the index to modify: "))
            new_value = input("Enter the new value: ")
            result = modify_element(my_list, index, new_value)
            print(result)

        elif choice == "3":
            start = int(input("Enter the start index for slice: "))
            end = int(input("Enter the end index for slice: "))
            result = slice_list(my_list, start, end)
            print(result)

        elif choice == "4":
            print("Thanks for playing!")
            break
        else:
            print("Invalid choice. Enter a number between 1 to 4.")

if __name__ == "__main__":
    list_game()
# Out:
# ***Lists and Dicts***
# ['apple', 'banana', 'cherry', 'orange', 'pear']
# Welcome to the List Manipulation Game
#
# Current list: ['apple', 'banana', 'cherry', 'orange', 'pear']
# Select an operation:
# 1. Access Element
# 2. Modify Element
# 3. Slice List
# 4. Quit
# Enter your choice (1/2/3/4): 1
# Enter the index to access: 2
# Element at index 2 is cherry
#
# Current list: ['apple', 'banana', 'cherry', 'orange', 'pear']
# Select an operation:
# 1. Access Element
# 2. Modify Element
# 3. Slice List
# 4. Quit
# Enter your choice (1/2/3/4): 2
# Enter the index to modify: 1
# Enter the new value: mango
# Element at index 1 modified from banana to mango
#
# Current list: ['apple', 'mango', 'cherry', 'orange', 'pear']
# Select an operation:
# 1. Access Element
# 2. Modify Element
# 3. Slice List
# 4. Quit
# Enter your choice (1/2/3/4): 3
# Enter the start index for slice: 1
# Enter the end index for slice: 5
# Sliced list: ['mango', 'cherry', 'orange', 'pear']
#
# ...
